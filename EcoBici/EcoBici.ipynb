# %% [markdown]
# #Analisis de datos de Eco Bici CDMX

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import zipfile
import io

# %% [markdown]
# ## Extracción de datos

# %% [markdown]
# Obtenemos los datos desde la página web de EcoBici

# %%
url = "https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/02/2025-01.csv"

csv_fil_name = "ecoBici_2025-01"

# %%
print(f"Descargado datos desde: {url}")
try:
  response = requests.get(url)
  response.raise_for_status()
  print("Descarga completada con exito")

except requests.exceptions.Timeout as e:
  print(f"Error de timeout durante la descarga: {e}")
  df_raw = pd.DataFrame()

except requests.exceptios.RequestException as e:
  print(f"Error durante la descarga: {e}")
  df_raw = pd.DataFrame()
# Out:
# Descargado datos desde: https://ecobici.cdmx.gob.mx/wp-content/uploads/2025/02/2025-01.csv
# Descarga completada con exito

# %%
with open(csv_fil_name, 'wb') as f:
  f.write(response.content)
  print(f"Archivo zip guardado como: {csv_fil_name}")

  print(f"Leyedo datos desde: {csv_fil_name}")
  df_raw = pd.read_csv(csv_fil_name)
  print("Extracción completa con exito")
# Out:
# Archivo zip guardado como: ecoBici_2025-01
# Leyedo datos desde: ecoBici_2025-01
# Extracción completa con exito

# %% [markdown]
# Muestra de los datos obtenidos

# %%
print("Tamaño del DataFrame:")
print(df_raw.shape)

print("\nPrevisualización del DataFrame:")
display(df_raw.head(50))
# Out:
# Tamaño del DataFrame:
# (1809775, 9)
#
# Previsualización del DataFrame:
#    Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0               M          26.0  5180930                   568   31/12/2024
# 1               F          54.0  3653953                   283   31/12/2024
# 2               M          38.0  7511322                   034   31/12/2024
# 3               M          41.0  3804572                   258   31/12/2024
# 4               M          35.0  3848405                   043   31/12/2024
# 5               M          24.0  7579436                   222   31/12/2024
# 6               M          31.0  7161920                   034   31/12/2024
# 7               M          22.0  7220593                   254   31/12/2024
# 8               M          29.0  4031258                   560   31/12/2024
# 9               F          24.0  6463376                   560   31/12/2024
# 10              M          45.0  5128335                   165   31/12/2024
# 11              F          25.0  8528846                   086   31/12/2024
# 12              M          30.0  2854065                   004   01/01/2025
# 13              F          29.0  6904098                   129   31/12/2024
# 14              M          55.0  8397085                   098   31/12/2024
# 15              M          30.0  5124706                   005   31/12/2024
# 16              M          31.0  7357643                   005   31/12/2024
# 17              M          30.0  4687174                   325   31/12/2024
# 18              F          23.0  8274672                   257   31/12/2024
# 19              M          31.0  2784072                   121   31/12/2024
# 20              F          35.0  5832985                   111   31/12/2024
# 21              M          31.0  2495554                   270   31/12/2024
# 22              M          27.0  5703863                   630   31/12/2024
# 23              M          22.0  7612336                   544   31/12/2024
# 24              F          23.0  5503149                   020   31/12/2024
# 25              F          20.0  3558525                   154   31/12/2024
# 26              M          26.0  6746051                   555   31/12/2024
# 27              F          29.0  3635000                   026   31/12/2024
# 28              M          49.0  7849797                   040   31/12/2024
# 29              M          45.0  3443207                   008   31/12/2024
# 30              F          39.0  8255051               390-391   31/12/2024
# 31              M          32.0  4509279                   145   31/12/2024
# 32              F          25.0  5042056                   145   31/12/2024
# 33              M          25.0  2228674                   399   31/12/2024
# 34              M          39.0  5974969                   046   31/12/2024
# 35              M          40.0  7374705                   046   31/12/2024
# 36              M          53.0  8608077                   601   31/12/2024
# 37              O          27.0  7903115                   389   31/12/2024
# 38              M          31.0  7255011                   085   31/12/2024
# 39              M          31.0  8023871                   303   31/12/2024
# 40              M          33.0  4259586                   064   01/01/2025
# 41              M          34.0  3821428                   136   31/12/2024
# 42              M          37.0  2196749                   539   31/12/2024
# 43              M          33.0  4716841                   086   31/12/2024
# 44              M          23.0  4549648                   528   31/12/2024
# 45              F          52.0  7195712                   041   01/01/2025
# 46              M          41.0  3667193                   016   31/12/2024
# 47              M          23.0  2514354                   041   31/12/2024
# 48              M          27.0  6422463                   105   31/12/2024
# 49              M          41.0  4608113                   185   01/01/2025
#
#    Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo
# 0     23:57:02                  572   01/01/2025    00:00:03
# 1     23:51:40                  596   01/01/2025    00:00:41
# 2     23:48:36                  064   01/01/2025    00:00:59
# 3     23:54:11                  023   01/01/2025    00:01:08
# 4     23:35:28                  126   01/01/2025    00:01:17
# 5     23:34:33                  483   01/01/2025    00:01:58
# 6     23:25:47                  688   01/01/2025    00:02:16
# 7     23:50:20                  539   01/01/2025    00:02:41
# 8     23:52:11                  120   01/01/2025    00:03:28
# 9     23:51:50                  120   01/01/2025    00:03:31
# 10    23:40:43                  085   01/01/2025    00:04:09
# 11    23:31:01                  518   01/01/2025    00:04:31
# 12    00:01:09                  001   01/01/2025    00:05:28
# 13    23:33:08                  002   01/01/2025    00:05:56
# 14    23:51:32                  010   01/01/2025    00:06:23
# 15    23:53:31                  495   01/01/2025    00:06:30
# 16    23:53:46                  495   01/01/2025    00:06:32
# 17    23:45:24                  113   01/01/2025    00:06:57
# 18    23:51:54                  534   01/01/2025    00:07:08
# 19    23:41:27                  327   01/01/2025    00:07:11
# 20    23:34:53                  257   01/01/2025    00:07:26
# 21    23:50:03                  031   01/01/2025    00:07:32
# 22    23:47:04                  385   01/01/2025    00:07:39
# 23    23:40:39                  030   01/01/2025    00:07:53
# 24    23:47:00                  450   01/01/2025    00:07:56
# 25    23:32:09                  624   01/01/2025    00:08:10
# 26    23:29:19                  595   01/01/2025    00:08:14
# 27    23:47:21                  014   01/01/2025    00:08:25
# 28    23:47:24                  009   01/01/2025    00:08:36
# 29    23:30:40                  003   01/01/2025    00:09:05
# 30    23:53:31                  441   01/01/2025    00:09:10
# 31    23:58:01                  047   01/01/2025    00:09:44
# 32    23:57:59                  047   01/01/2025    00:09:52
# 33    23:48:58                  329   01/01/2025    00:09:53
# 34    23:51:18                  140   01/01/2025    00:10:01
# 35    23:53:11                  140   01/01/2025    00:10:04
# 36    23:56:11                  609   01/01/2025    00:10:21
# 37    23:51:45                  635   01/01/2025    00:10:38
# 38    23:48:16                  006   01/01/2025    00:11:11
# 39    23:59:17                  373   01/01/2025    00:11:13
# 40    00:01:36                  291   01/01/2025    00:11:16
# 41    23:46:36                  033   01/01/2025    00:11:40
# 42    23:55:29                  005   01/01/2025    00:11:40
# 43    23:37:33                  448   01/01/2025    00:11:42
# 44    23:48:15                  257   01/01/2025    00:12:27
# 45    00:06:50                  118   01/01/2025    00:12:50
# 46    23:23:56                  547   01/01/2025    00:12:53
# 47    23:25:52                  685   01/01/2025    00:13:09
# 48    23:56:17                  026   01/01/2025    00:13:18
# 49    00:06:58                  081   01/01/2025    00:13:22

# %% [markdown]
# ## Limpieza de datos
#
# Se busca obtener una mejora en los modelos. Este es uno de los procesos más importantes.
#
# Librerias principales para la limpieza:
# * Pandas -> Data manipulation, filtering, joins, reshaping
# * Numpy -> Numerical computation and vertical something
# * Scikit-learn
#
# Estrategias:
# * Eliminar columnas con MUCHOS datos vacios
# * Imputar los datos faltantes con la media (promedio) o la mediana (valor de en medio)
# * Convertir los valores vacios en "default" -> 0
# * Usar modelos predictivos

# %%
print("\nTipos de datos antes de la conversación a datetime")
print(df_raw.dtypes)
# Out:
# Tipos de datos antes de la conversación a datetime
# Genero_Usuario            object
# Edad_Usuario             float64
# Bici                       int64
# Ciclo_Estacion_Retiro     object
# Fecha_Retiro              object
# Hora_Retiro               object
# Ciclo_EstacionArribo      object
# Fecha_Arribo              object
# Hora_Arribo               object
# dtype: object

# %%
df_raw.isnull().sum()
# Out:
# Genero_Usuario             1
# Edad_Usuario             147
# Bici                       0
# Ciclo_Estacion_Retiro      0
# Fecha_Retiro               0
# Hora_Retiro                0
# Ciclo_EstacionArribo       0
# Fecha_Arribo               0
# Hora_Arribo                0
# dtype: int64

# %%
print(f"Edades nulas: {df_raw['Edad_Usuario'].isnull().sum()}")
print(f"Edades no nulas: {df_raw['Edad_Usuario'].notnull().sum()}")
# Out:
# Edades nulas: 147
# Edades no nulas: 1809628

# %%
# Ponemos la mediana en las edades faltantes para no generar outliers
df_raw['Edad_Usuario'] = df_raw['Edad_Usuario'].fillna(df_raw['Edad_Usuario'].median())

# %%
df_raw.isnull().sum()
# Out:
# Genero_Usuario           1
# Edad_Usuario             0
# Bici                     0
# Ciclo_Estacion_Retiro    0
# Fecha_Retiro             0
# Hora_Retiro              0
# Ciclo_EstacionArribo     0
# Fecha_Arribo             0
# Hora_Arribo              0
# dtype: int64

# %%
df_raw['Edad_Usuario'] = df_raw['Edad_Usuario'].astype(int)

# %% [markdown]
# # Ejercicio: media, mediana y moda (25 de agosto de 2025)
#
# Calcular las medias de tendencia central de todas las columnas que aplique

# %%
print(f"Media de la edad: {df_raw['Edad_Usuario'].mean(): .2f}")
print(f"Mediana de la edad: {df_raw['Edad_Usuario'].median()}")
print(f"Moda de la edad: {df_raw['Edad_Usuario'].mode()}")
# Out:
# Media de la edad:  34.00
# Mediana de la edad: 32.0
# Moda de la edad: 0    30
# Name: Edad_Usuario, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_raw['Edad_Usuario'], bins=30, edgecolor='black')
plt.title('Distribución de Edades de los Usuarios')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
