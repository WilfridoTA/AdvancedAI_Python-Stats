# %% [markdown]
# # Esta cosa es para analizar una base de datos de Airbnb

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('listings.csv')
columns = data.columns.size
rows = len(data)

print(columns, rows)
# Out:
# 79 26067

# %%
data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  35797  https://www.airbnb.com/rooms/35797  20250319150644   2025-03-21
# 1  44616  https://www.airbnb.com/rooms/44616  20250319150644   2025-03-20
# 2  56074  https://www.airbnb.com/rooms/56074  20250319150644   2025-03-20
# 3  67703  https://www.airbnb.com/rooms/67703  20250319150644   2025-03-20
# 4  70644  https://www.airbnb.com/rooms/70644  20250319150644   2025-03-22
#
#             source                                              name  \
# 0      city scrape                                       Villa Dante
# 1  previous scrape                                      Condesa Haus
# 2      city scrape              Great space in historical San Rafael
# 3  previous scrape                 2 bedroom apt. deco bldg, Condesa
# 4      city scrape  Beautiful light Studio Coyoacan- full equipped !
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  This great apartment is located in one of the ...
# 3  Comfortably furnished, sunny, 2 bedroom apt., ...
# 4  COYOACAN designer studio quiet & safe! well eq...
#
#                                neighborhood_overview  \
# 0  Santa Fe Shopping Mall, Interlomas Park and th...
# 1                                                NaN
# 2  Very traditional neighborhood with all service...
# 3                                                NaN
# 4  Coyoacan is a beautiful neighborhood famous fo...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...   153786  ...
# 1  https://a0.muscache.com/pictures/251410/ec75fe...   196253  ...
# 2  https://a0.muscache.com/pictures/3005118/60dac...   265650  ...
# 3  https://a0.muscache.com/pictures/3281720/6f078...   334451  ...
# 4  https://a0.muscache.com/pictures/f397d2da-d045...   212109  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                        4.78                   4.98                4.47
# 2                        4.94                   4.76                4.79
# 3                        4.92                   4.98                4.92
# 4                        4.98                   4.96                4.92
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              9
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              3
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           4
# 2                                           1
# 3                                           2
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            0
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              0.40
# 2                                           0              0.49
# 3                                           0              0.31
# 4                                           0              0.83
#
# [5 rows x 79 columns]

# %%
print(data.columns.values)
# Out:
# ['id' 'listing_url' 'scrape_id' 'last_scraped' 'source' 'name'
#  'description' 'neighborhood_overview' 'picture_url' 'host_id' 'host_url'
#  'host_name' 'host_since' 'host_location' 'host_about'
#  'host_response_time' 'host_response_rate' 'host_acceptance_rate'
#  'host_is_superhost' 'host_thumbnail_url' 'host_picture_url'
#  'host_neighbourhood' 'host_listings_count' 'host_total_listings_count'
#  'host_verifications' 'host_has_profile_pic' 'host_identity_verified'
#  'neighbourhood' 'neighbourhood_cleansed' 'neighbourhood_group_cleansed'
#  'latitude' 'longitude' 'property_type' 'room_type' 'accommodates'
#  'bathrooms' 'bathrooms_text' 'bedrooms' 'beds' 'amenities' 'price'
#  'minimum_nights' 'maximum_nights' 'minimum_minimum_nights'
#  'maximum_minimum_nights' 'minimum_maximum_nights'
#  'maximum_maximum_nights' 'minimum_nights_avg_ntm'
#  'maximum_nights_avg_ntm' 'calendar_updated' 'has_availability'
#  'availability_30' 'availability_60' 'availability_90' 'availability_365'
#  'calendar_last_scraped' 'number_of_reviews' 'number_of_reviews_ltm'
#  'number_of_reviews_l30d' 'availability_eoy' 'number_of_reviews_ly'
#  'estimated_occupancy_l365d' 'estimated_revenue_l365d' 'first_review'
#  'last_review' 'review_scores_rating' 'review_scores_accuracy'
#  'review_scores_cleanliness' 'review_scores_checkin'
#  'review_scores_communication' 'review_scores_location'
#  'review_scores_value' 'license' 'instant_bookable'
#  'calculated_host_listings_count'
#  'calculated_host_listings_count_entire_homes'
#  'calculated_host_listings_count_private_rooms'
#  'calculated_host_listings_count_shared_rooms' 'reviews_per_month']

# %% [markdown]
# # Actividad
#
# Obtener:
#
# * mean price
# * room_type más común
# * 10 alcaldías con más alojamiento
# * Las 10 personas con más alojamientos (host_name)

# %% [markdown]
# ## Precio promedio

# %%
# Visualizamos los valores de la columna
data['price']
# Out:
# 0        $3,982.00
# 1              NaN
# 2          $585.00
# 3              NaN
# 4        $1,015.00
#            ...
# 26062      $529.00
# 26063      $472.00
# 26064      $399.00
# 26065    $1,494.00
# 26066    $1,722.00
# Name: price, Length: 26067, dtype: object

# %%
#Eliminar valores nulos
data = data.dropna(subset=['price'])

data['price']
# Out:
# 0        $3,982.00
# 2          $585.00
# 4        $1,015.00
# 6        $3,982.00
# 7          $327.00
#            ...
# 26062      $529.00
# 26063      $472.00
# 26064      $399.00
# 26065    $1,494.00
# 26066    $1,722.00
# Name: price, Length: 22068, dtype: object

# %%
#Limpiar $ , de los precios
data['price'] = data['price'].str.replace('$', '').str.replace(',', '')
data['price']
# Out:
# 0        3982.00
# 2         585.00
# 4        1015.00
# 6        3982.00
# 7         327.00
#           ...
# 26062     529.00
# 26063     472.00
# 26064     399.00
# 26065    1494.00
# 26066    1722.00
# Name: price, Length: 22068, dtype: object

# %%
#Convertir str a float
data['price'] = data['price'].astype(float)
data['price']
# Out:
# 0        3982.0
# 2         585.0
# 4        1015.0
# 6        3982.0
# 7         327.0
#           ...
# 26062     529.0
# 26063     472.0
# 26064     399.0
# 26065    1494.0
# 26066    1722.0
# Name: price, Length: 22068, dtype: float64

# %%
promedioPrem = data['price'].mean()
print("El precio promedio de una noche es: $", promedioPrem.round(2))
# Out:
# El precio promedio de una noche es: $ 1665.01

# %% [markdown]
# ## Tipo de habitación más común

# %%
data['room_type']
# Out:
# 0        Entire home/apt
# 2        Entire home/apt
# 4        Entire home/apt
# 6        Entire home/apt
# 7           Private room
#               ...
# 26062        Shared room
# 26063       Private room
# 26064       Private room
# 26065    Entire home/apt
# 26066    Entire home/apt
# Name: room_type, Length: 22068, dtype: object

# %%
data['room_type'].value_counts().head(1)
# Out:
# room_type
# Entire home/apt    14843
# Name: count, dtype: int64

# %%
data['room_type'].value_counts().head()
#Graficamos los tipos de habitación
figHab, axHab = plt.subplots()
axHab.bar(data['room_type'].value_counts().head().index, data['room_type'].value_counts().head().values)
axHab.set_title("Tipos de habitación")
# Out:
# Text(0.5, 1.0, 'Tipos de habitación')

# %% [markdown]
# Graficando los datos nos podemos dar cuenta de que el principal tipo de habitación son casas y departamentos completos, seguido por la renta de cuartos individuales.

# %% [markdown]
# ## 10 alcaldías con más alojamiento

# %%
data = data.dropna(subset=['host_neighbourhood'])

# %%
data['host_neighbourhood'].value_counts().head(10)
# Out:
# host_neighbourhood
# Polanco                                    1487
# Roma Norte                                 1002
# Condesa                                     645
# Chapultepec Morales                         605
# Centro Histórico de la Ciudad de México     460
# Hipódromo                                   368
# Colonia Cuauhtémoc                          364
# Colonia Centro                              356
# Centro Histórico                            310
# Coapa                                       224
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,10))
plt.bar(data['host_neighbourhood'].value_counts().head(10).index, data['host_neighbourhood'].value_counts().head(10).values)
plt.title('Alcaldías con más Airbnb')
plt.ylabel('Cantidad de Airbnb')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Las 10 personas con más alojamientos

# %%
data['host_name'].value_counts().head(10)
# Out:
# host_name
# Blueground    225
# Juan          207
# Mr. W         201
# Capitalia     154
# Alejandra     141
# Luis          137
# Alejandro     135
# Andrea        118
# Eduardo       108
# HOMi          105
# Name: count, dtype: int64

# %%
figPer, axPer = plt.subplots(figsize=(8, 5))
axPer.bar(data['host_name'].value_counts().head(10).index, data['host_name'].value_counts().head(10).values)
axPer.set_title("Personas con más Airbnb")
# Out:
# Text(0.5, 1.0, 'Personas con más Airbnb')

# %% [markdown]
# ### Segunda parte de la actividad
#
# * Histograma de distribución de precios (frecuencia)
# * Gráfica de barras para los tipos de alojamiento vs cantidad
# * Gráfica de barras: horizontal del top 10 alcaldías
# * Distribución geografica de precios [scatter_mapbox]

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['price'], bins=30, range=(0, 15000)) # Agregamos el rango para mostrar los principales precios
plt.title('Histograma de precios')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Es importante mencionar que el histograma tiene un límite hasta 15,000 porque después de ese valor no hay ni un solo dato hasta llegar al precio más alto 438,000

# %%
data['price']
# Out:
# 2         585.0
# 4        1015.0
# 6        3982.0
# 7         327.0
# 8         605.0
#           ...
# 26058     846.0
# 26060     228.0
# 26061     448.0
# 26062     529.0
# 26065    1494.0
# Name: price, Length: 11998, dtype: float64

# %%
plt.figure()
plt.bar(data['room_type'].value_counts().head().index, data['room_type'].value_counts().head().values)
plt.title('Tipo de alojamiento')
plt.ylabel('Cantidad de alojamientos')
plt.show()

# %% [markdown]
# ## Distribución geográfica de precios scatter_mapbox

# %%
import plotly.express as px

# %%
fig = px.scatter_map(data,
                        lon = data['longitude'],
                        lat = data['latitude'],
                        zoom = 10,
                        color = data['price'],
                        size = data['price'], #Cambia el tamaño de los puntos de acuerdo con el precio
                        title = "Distribución geográfica de precios",
                        )

fig.show()

# %% [markdown]
# # Ejercicio: media, mediana y moda (25 de agosto de 2025)
#
# Calcular las medias de tendencia central de todas las columnas que aplique.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11998 entries, 2 to 26065
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            11998 non-null  int64
#  1   listing_url                                   11998 non-null  object
#  2   scrape_id                                     11998 non-null  int64
#  3   last_scraped                                  11998 non-null  object
#  4   source                                        11998 non-null  object
#  5   name                                          11998 non-null  object
#  6   description                                   11727 non-null  object
#  7   neighborhood_overview                         6872 non-null   object
#  8   picture_url                                   11998 non-null  object
#  9   host_id                                       11998 non-null  int64
#  10  host_url                                      11998 non-null  object
#  11  host_name                                     11998 non-null  object
#  12  host_since                                    11998 non-null  object
#  13  host_location                                 9887 non-null   object
#  14  host_about                                    8216 non-null   object
#  15  host_response_time                            11580 non-null  object
#  16  host_response_rate                            11580 non-null  object
#  17  host_acceptance_rate                          11707 non-null  object
#  18  host_is_superhost                             11180 non-null  object
#  19  host_thumbnail_url                            11998 non-null  object
#  20  host_picture_url                              11998 non-null  object
#  21  host_neighbourhood                            11998 non-null  object
#  22  host_listings_count                           11998 non-null  float64
#  23  host_total_listings_count                     11998 non-null  float64
#  24  host_verifications                            11998 non-null  object
#  25  host_has_profile_pic                          11998 non-null  object
#  26  host_identity_verified                        11998 non-null  object
#  27  neighbourhood                                 6872 non-null   object
#  28  neighbourhood_cleansed                        11998 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      11998 non-null  float64
#  31  longitude                                     11998 non-null  float64
#  32  property_type                                 11998 non-null  object
#  33  room_type                                     11998 non-null  object
#  34  accommodates                                  11998 non-null  int64
#  35  bathrooms                                     11994 non-null  float64
#  36  bathrooms_text                                11988 non-null  object
#  37  bedrooms                                      11961 non-null  float64
#  38  beds                                          11985 non-null  float64
#  39  amenities                                     11998 non-null  object
#  40  price                                         11998 non-null  float64
#  41  minimum_nights                                11998 non-null  int64
#  42  maximum_nights                                11998 non-null  int64
#  43  minimum_minimum_nights                        11998 non-null  int64
#  44  maximum_minimum_nights                        11998 non-null  int64
#  45  minimum_maximum_nights                        11998 non-null  int64
#  46  maximum_maximum_nights                        11998 non-null  int64
#  47  minimum_nights_avg_ntm                        11998 non-null  float64
#  48  maximum_nights_avg_ntm                        11998 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              11916 non-null  object
#  51  availability_30                               11998 non-null  int64
#  52  availability_60                               11998 non-null  int64
#  53  availability_90                               11998 non-null  int64
#  54  availability_365                              11998 non-null  int64
#  55  calendar_last_scraped                         11998 non-null  object
#  56  number_of_reviews                             11998 non-null  int64
#  57  number_of_reviews_ltm                         11998 non-null  int64
#  58  number_of_reviews_l30d                        11998 non-null  int64
#  59  availability_eoy                              11998 non-null  int64
#  60  number_of_reviews_ly                          11998 non-null  int64
#  61  estimated_occupancy_l365d                     11998 non-null  int64
#  62  estimated_revenue_l365d                       11998 non-null  float64
#  63  first_review                                  10864 non-null  object
#  64  last_review                                   10864 non-null  object
#  65  review_scores_rating                          10864 non-null  float64
#  66  review_scores_accuracy                        10863 non-null  float64
#  67  review_scores_cleanliness                     10863 non-null  float64
#  68  review_scores_checkin                         10863 non-null  float64
#  69  review_scores_communication                   10863 non-null  float64
#  70  review_scores_location                        10863 non-null  float64
#  71  review_scores_value                           10863 non-null  float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              11998 non-null  object
#  74  calculated_host_listings_count                11998 non-null  int64
#  75  calculated_host_listings_count_entire_homes   11998 non-null  int64
#  76  calculated_host_listings_count_private_rooms  11998 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   11998 non-null  int64
#  78  reviews_per_month                             10864 non-null  float64
# dtypes: float64(22), int64(24), object(33)
# memory usage: 7.3+ MB

# %%
data.describe().T
# Out:
#                                                 count          mean  \
# id                                            11998.0  6.384131e+17
# scrape_id                                     11998.0  2.025032e+13
# host_id                                       11998.0  2.063944e+08
# host_listings_count                           11998.0  4.108485e+01
# host_total_listings_count                     11998.0  5.661094e+01
# neighbourhood_group_cleansed                      0.0           NaN
# latitude                                      11998.0  1.941019e+01
# longitude                                     11998.0 -9.916817e+01
# accommodates                                  11998.0  3.554009e+00
# bathrooms                                     11994.0  1.516091e+00
# bedrooms                                      11961.0  1.594934e+00
# beds                                          11985.0  2.038882e+00
# price                                         11998.0  1.877007e+03
# minimum_nights                                11998.0  3.661444e+00
# maximum_nights                                11998.0  5.046326e+02
# minimum_minimum_nights                        11998.0  2.940157e+00
# maximum_minimum_nights                        11998.0  3.665278e+00
# minimum_maximum_nights                        11998.0  7.084232e+02
# maximum_maximum_nights                        11998.0  7.384733e+02
# minimum_nights_avg_ntm                        11998.0  3.246283e+00
# maximum_nights_avg_ntm                        11998.0  7.217202e+02
# calendar_updated                                  0.0           NaN
# availability_30                               11998.0  1.359818e+01
# availability_60                               11998.0  3.540982e+01
# availability_90                               11998.0  5.976138e+01
# availability_365                              11998.0  2.412907e+02
# number_of_reviews                             11998.0  6.049892e+01
# number_of_reviews_ltm                         11998.0  1.729272e+01
# number_of_reviews_l30d                        11998.0  1.414819e+00
# availability_eoy                              11998.0  1.967242e+02
# number_of_reviews_ly                          11998.0  1.635531e+01
# estimated_occupancy_l365d                     11998.0  9.559343e+01
# estimated_revenue_l365d                       11998.0  1.596195e+05
# review_scores_rating                          10864.0  4.748887e+00
# review_scores_accuracy                        10863.0  4.783722e+00
# review_scores_cleanliness                     10863.0  4.759473e+00
# review_scores_checkin                         10863.0  4.841017e+00
# review_scores_communication                   10863.0  4.819933e+00
# review_scores_location                        10863.0  4.859560e+00
# review_scores_value                           10863.0  4.709987e+00
# license                                           0.0           NaN
# calculated_host_listings_count                11998.0  2.286398e+01
# calculated_host_listings_count_entire_homes   11998.0  1.950483e+01
# calculated_host_listings_count_private_rooms  11998.0  3.073929e+00
# calculated_host_listings_count_shared_rooms   11998.0  2.610435e-01
# reviews_per_month                             10864.0  1.983490e+00
#
#                                                        std           min  \
# id                                            5.440094e+17  5.607400e+04
# scrape_id                                     0.000000e+00  2.025032e+13
# host_id                                       1.966212e+08  1.224300e+04
# host_listings_count                           1.179591e+02  1.000000e+00
# host_total_listings_count                     1.679490e+02  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      3.591966e-02  1.909576e+01
# longitude                                     2.888067e-02 -9.932164e+01
# accommodates                                  2.533900e+00  1.000000e+00
# bathrooms                                     1.193310e+00  0.000000e+00
# bedrooms                                      1.421833e+00  0.000000e+00
# beds                                          1.938513e+00  0.000000e+00
# price                                         5.335579e+03  1.350000e+02
# minimum_nights                                1.404532e+01  1.000000e+00
# maximum_nights                                3.990670e+02  1.000000e+00
# minimum_minimum_nights                        1.297512e+01  1.000000e+00
# maximum_minimum_nights                        1.387863e+01  1.000000e+00
# minimum_maximum_nights                        4.362918e+02  1.000000e+00
# maximum_maximum_nights                        4.679196e+02  1.000000e+00
# minimum_nights_avg_ntm                        1.325518e+01  1.000000e+00
# maximum_nights_avg_ntm                        4.346343e+02  1.000000e+00
# calendar_updated                                       NaN           NaN
# availability_30                               9.959298e+00  0.000000e+00
# availability_60                               1.873291e+01  0.000000e+00
# availability_90                               2.672202e+01  0.000000e+00
# availability_365                              1.156202e+02  0.000000e+00
# number_of_reviews                             8.885440e+01  0.000000e+00
# number_of_reviews_ltm                         2.204458e+01  0.000000e+00
# number_of_reviews_l30d                        1.985243e+00  0.000000e+00
# availability_eoy                              8.829391e+01  0.000000e+00
# number_of_reviews_ly                          2.187765e+01  0.000000e+00
# estimated_occupancy_l365d                     9.155315e+01  0.000000e+00
# estimated_revenue_l365d                       3.237437e+05  0.000000e+00
# review_scores_rating                          3.566509e-01  1.000000e+00
# review_scores_accuracy                        3.499458e-01  1.000000e+00
# review_scores_cleanliness                     3.507643e-01  1.000000e+00
# review_scores_checkin                         2.989703e-01  1.000000e+00
# review_scores_communication                   3.411407e-01  1.000000e+00
# review_scores_location                        2.521735e-01  1.000000e+00
# review_scores_value                           3.769578e-01  1.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                4.556225e+01  1.000000e+00
# calculated_host_listings_count_entire_homes   4.578241e+01  0.000000e+00
# calculated_host_listings_count_private_rooms  8.344900e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   2.221696e+00  0.000000e+00
# reviews_per_month                             1.988027e+00  1.000000e-02
#
#                                                        25%           50%  \
# id                                            3.926576e+07  7.914731e+17
# scrape_id                                     2.025032e+13  2.025032e+13
# host_id                                       4.010428e+07  1.292829e+08
# host_listings_count                           2.000000e+00  8.000000e+00
# host_total_listings_count                     3.000000e+00  9.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      1.940305e+01  1.941797e+01
# longitude                                    -9.917883e+01 -9.916774e+01
# accommodates                                  2.000000e+00  3.000000e+00
# bathrooms                                     1.000000e+00  1.000000e+00
# bedrooms                                      1.000000e+00  1.000000e+00
# beds                                          1.000000e+00  2.000000e+00
# price                                         7.030000e+02  1.166000e+03
# minimum_nights                                1.000000e+00  2.000000e+00
# maximum_nights                                3.650000e+02  3.650000e+02
# minimum_minimum_nights                        1.000000e+00  1.000000e+00
# maximum_minimum_nights                        1.000000e+00  2.000000e+00
# minimum_maximum_nights                        3.650000e+02  1.095000e+03
# maximum_maximum_nights                        3.650000e+02  1.125000e+03
# minimum_nights_avg_ntm                        1.000000e+00  2.000000e+00
# maximum_nights_avg_ntm                        3.650000e+02  1.119800e+03
# calendar_updated                                       NaN           NaN
# availability_30                               5.000000e+00  1.300000e+01
# availability_60                               2.200000e+01  3.900000e+01
# availability_90                               4.700000e+01  6.700000e+01
# availability_365                              1.480000e+02  2.770000e+02
# number_of_reviews                             5.000000e+00  2.500000e+01
# number_of_reviews_ltm                         2.000000e+00  1.000000e+01
# number_of_reviews_l30d                        0.000000e+00  1.000000e+00
# availability_eoy                              1.360000e+02  2.370000e+02
# number_of_reviews_ly                          1.000000e+00  8.000000e+00
# estimated_occupancy_l365d                     1.200000e+01  6.600000e+01
# estimated_revenue_l365d                       1.116150e+04  6.858900e+04
# review_scores_rating                          4.690000e+00  4.830000e+00
# review_scores_accuracy                        4.750000e+00  4.870000e+00
# review_scores_cleanliness                     4.710000e+00  4.850000e+00
# review_scores_checkin                         4.815000e+00  4.910000e+00
# review_scores_communication                   4.800000e+00  4.910000e+00
# review_scores_location                        4.830000e+00  4.930000e+00
# review_scores_value                           4.660000e+00  4.790000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                2.000000e+00  6.000000e+00
# calculated_host_listings_count_entire_homes   1.000000e+00  3.000000e+00
# calculated_host_listings_count_private_rooms  0.000000e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             6.300000e-01  1.520000e+00
#
#                                                        75%           max
# id                                            1.150759e+18  1.379807e+18
# scrape_id                                     2.025032e+13  2.025032e+13
# host_id                                       3.592652e+08  6.844740e+08
# host_listings_count                           2.600000e+01  8.860000e+02
# host_total_listings_count                     3.300000e+01  1.049000e+03
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      1.943285e+01  1.951744e+01
# longitude                                    -9.915569e+01 -9.897911e+01
# accommodates                                  4.000000e+00  1.600000e+01
# bathrooms                                     2.000000e+00  4.900000e+01
# bedrooms                                      2.000000e+00  5.000000e+01
# beds                                          2.000000e+00  5.000000e+01
# price                                         1.933000e+03  4.380530e+05
# minimum_nights                                2.000000e+00  7.290000e+02
# maximum_nights                                1.125000e+03  1.125000e+03
# minimum_minimum_nights                        2.000000e+00  7.290000e+02
# maximum_minimum_nights                        3.000000e+00  7.290000e+02
# minimum_maximum_nights                        1.125000e+03  1.125000e+03
# maximum_maximum_nights                        1.125000e+03  9.999000e+03
# minimum_nights_avg_ntm                        2.200000e+00  7.290000e+02
# maximum_nights_avg_ntm                        1.125000e+03  4.877800e+03
# calendar_updated                                       NaN           NaN
# availability_30                               2.200000e+01  3.000000e+01
# availability_60                               5.100000e+01  6.000000e+01
# availability_90                               8.100000e+01  9.000000e+01
# availability_365                              3.460000e+02  3.650000e+02
# number_of_reviews                             7.900000e+01  1.291000e+03
# number_of_reviews_ltm                         2.600000e+01  5.390000e+02
# number_of_reviews_l30d                        2.000000e+00  4.400000e+01
# availability_eoy                              2.690000e+02  2.880000e+02
# number_of_reviews_ly                          2.500000e+01  5.490000e+02
# estimated_occupancy_l365d                     1.680000e+02  2.550000e+02
# estimated_revenue_l365d                       2.017710e+05  1.914206e+07
# review_scores_rating                          4.930000e+00  5.000000e+00
# review_scores_accuracy                        4.950000e+00  5.000000e+00
# review_scores_cleanliness                     4.940000e+00  5.000000e+00
# review_scores_checkin                         4.990000e+00  5.000000e+00
# review_scores_communication                   5.000000e+00  5.000000e+00
# review_scores_location                        5.000000e+00  5.000000e+00
# review_scores_value                           4.900000e+00  5.000000e+00
# license                                                NaN           NaN
# calculated_host_listings_count                2.000000e+01  2.420000e+02
# calculated_host_listings_count_entire_homes   1.300000e+01  2.420000e+02
# calculated_host_listings_count_private_rooms  2.000000e+00  6.500000e+01
# calculated_host_listings_count_shared_rooms   0.000000e+00  2.800000e+01
# reviews_per_month                             2.790000e+00  4.461000e+01

# %%
meanPrice = data['price'].mean()
medianaPrice = data['price'].median()
modePrice = data['price'].mode()

print(f"El precio promedio de una noche es: ${meanPrice.round(2)} \nLa mediana del precio es: ${medianaPrice}\nLa moda del precio es: ${modePrice}")
# Out:
# El precio promedio de una noche es: $1877.01
# La mediana del precio es: $1166.0
# La moda del precio es: $0    900.0
# Name: price, dtype: float64

# %%
meanBedrooms = data['bedrooms'].mean()
medianaBedrooms = data['bedrooms'].median()
modeBedrooms = data['bedrooms'].mode()

print(f"Habitaciones en promedio: {meanBedrooms.round(2)} \nMediana de habitaciones: {medianaBedrooms}\nModa de habitaciones: ${modeBedrooms}")
# Out:
# Habitaciones en promedio: 1.59
# Mediana de habitaciones: 1.0
# Moda de habitaciones: $0    1.0
# Name: bedrooms, dtype: float64

# %%
meanBeds = data['beds'].mean()
medianBeds = data['beds'].median()
modeBeds = data['beds'].mode()

print(f"Camas en promedio: {meanBeds.round(2)} \nMediana de camas: {medianBeds} \nModa de camas: {modeBeds}")
# Out:
# Camas en promedio: 2.04
# Mediana de camas: 2.0
# Moda de camas: 0    1.0
# Name: beds, dtype: float64
