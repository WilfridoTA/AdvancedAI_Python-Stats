# %% [markdown]
# __10 de septiembre de 2025__
#
# *   Guillermo Ian Barbosa Martínez - A01747926
# *   Arely Yael Villatoro Amador    - A01663303
# *   Ariel Lopez Garcia             - A01275913
# *   Wilfrido Tovar Andrade         - A01664769
# *   Lukas David Knierim            - A01830296
# *   Carlo Crivelli Hernandez       - A01656171

# %% [markdown]
# # Librerias y Archivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Extracción de datos

# %%
path = "/content/drive/MyDrive/IA_Avanzada/Stats/Spotify_Activities/Most Streamed Spotify Songs 2024.csv"

df = pd.read_csv(path, encoding="cp1252")
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
summary = pd.DataFrame({
    "missing": df.isna().sum(),
    "present": df.notna().sum(),
    "missing_%": (df.isna().mean() * 100).round(2)
}).sort_values("missing", ascending=False)
summary[summary["missing_%"] > 0]
# Out:
#                             missing  present  missing_%
# TIDAL Popularity               4600        0     100.00
# Soundcloud Streams             3333     1267      72.46
# SiriusXM Spins                 2123     2477      46.15
# Pandora Track Stations         1268     3332      27.57
# TikTok Posts                   1173     3427      25.50
# Pandora Streams                1106     3494      24.04
# Amazon Playlist Count          1055     3545      22.93
# YouTube Playlist Reach         1009     3591      21.93
# TikTok Views                    981     3619      21.33
# TikTok Likes                    980     3620      21.30
# Deezer Playlist Reach           928     3672      20.17
# Deezer Playlist Count           921     3679      20.02
# Spotify Popularity              804     3796      17.48
# Shazam Counts                   577     4023      12.54
# Apple Music Playlist Count      561     4039      12.20
# AirPlay Spins                   498     4102      10.83
# ...

# %% [markdown]
# #Limpieza de datos

# %% [markdown]
# ## Datos faltantes

# %%
#Delete Tidal Popularity and Soundcloud streams as more than 70% of the values are missing, remove ISRC because it doesnt hold any value?

df = df.drop(columns=["TIDAL Popularity", "Soundcloud Streams", "ISRC"], errors="ignore")
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024             1        725.4     390,470,936
# 1     5/4/2024             2        545.9     323,703,884
# 2    3/19/2024             3        538.4     601,309,283
# 3    1/12/2023             4        444.9   2,031,280,633
# 4    5/31/2024             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  ...  \
# 0                 30,716            196,631,588                92.0  ...
# ...

# %%
#Treat Missing Values -> Replace Streaming Data with 0

df[["SiriusXM Spins", "Pandora Track Stations", "TikTok Posts", "Pandora Streams", "Amazon Playlist Count","YouTube Playlist Reach",
    "TikTok Views", "TikTok Likes","Deezer Playlist Reach","Deezer Playlist Count"	,"Spotify Popularity","Shazam Counts",
    "Apple Music Playlist Count","AirPlay Spins", "YouTube Likes","YouTube Views",
    "Spotify Streams","Spotify Playlist Reach","Spotify Playlist Count"]] = df[["SiriusXM Spins", "Pandora Track Stations", "TikTok Posts",
                                                                                "Pandora Streams", "Amazon Playlist Count","YouTube Playlist Reach",
                                                                                "TikTok Views", "TikTok Likes","Deezer Playlist Reach",
                                                                                "Deezer Playlist Count"	,"Spotify Popularity","Shazam Counts",
                                                                                "Apple Music Playlist Count","AirPlay Spins", "YouTube Likes",
                                                                                "YouTube Views","Spotify Streams","Spotify Playlist Reach",
                                                                                "Spotify Playlist Count"]].fillna(0)
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024             1        725.4     390,470,936
# 1     5/4/2024             2        545.9     323,703,884
# 2    3/19/2024             3        538.4     601,309,283
# 3    1/12/2023             4        444.9   2,031,280,633
# 4    5/31/2024             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  ...  \
# 0                 30,716            196,631,588                92.0  ...
# ...

# %% [markdown]
# ## Tratamiento de duplicados

# %%
# make sure column exists and is stringy
df["Track"] = df["Track"].astype(str)

# rows where Track appears more than once (exact match)
mask = df["Track"].duplicated(keep=False)
dups = (df.loc[mask, ["Track","Artist","Album Name","Release Date"]]
          .sort_values("Track"))
display(dups.head())

# counts per duplicated track
dup_counts = df["Track"].value_counts()
dup_counts = dup_counts[dup_counts > 1].sort_values(ascending=False)
print(f"Found {len(dup_counts)} duplicated track names.")
display(dup_counts.head())
# Out:
#           Track             Artist  \
# 3185       2002         Anne-Marie
# 3819       2002         Anne-Marie
# 2527         23     Chayce Beckham
# 3424         23  Mike WiLL Made-It
# 1350  24K Magic         Bruno Mars
#
#                                              Album Name Release Date
# 3185                                    Speak Your Mind     1/1/2015
# 3819                  NOW That's What I Call Music! 100    7/20/2018
# 2527                                                 23    5/14/2021
# 3424  23 (feat. Miley Cyrus, Wiz Khalifa & Juicy J) ...     1/1/2013
# 1350                                          24K Magic    10/7/2016
# Found 182 duplicated track names.
# Track
# Danza Kuduro - Cover         13
# Cake By The Ocean - Cover     9
# ýýýýýýýýýýýý                  7
# ýýýýýý                        6
# Alone                         4
# Name: count, dtype: int64

# %%
mask = df["Track"].duplicated(keep=False)
dup_rows = df.loc[mask].sort_values("Track")
dup_rows.head()
# Out:
#           Track                                         Album Name  \
# 3185       2002                                    Speak Your Mind
# 3819       2002                  NOW That's What I Call Music! 100
# 2527         23                                                 23
# 3424         23  23 (feat. Miley Cyrus, Wiz Khalifa & Juicy J) ...
# 1350  24K Magic                                          24K Magic
#
#                  Artist Release Date All Time Rank  Track Score  \
# 3185         Anne-Marie     1/1/2015         3,160         24.5
# 3819         Anne-Marie    7/20/2018         3,807         21.9
# 2527     Chayce Beckham    5/14/2021         2,511         28.3
# 3424  Mike WiLL Made-It     1/1/2013         3,409         23.5
# 1350         Bruno Mars    10/7/2016         1,340         40.6
#
#      Spotify Streams Spotify Playlist Count Spotify Playlist Reach  \
# 3185   1,531,490,541                115,663             31,287,443
# ...

# %%
# Canciones iguales vs. Artista diferente
count=0
print("Ejemplos de tracks duplicados con artista diferente:")
duplicate_tracks = df[df.duplicated(subset=['Track'], keep=False)].sort_values(by='Track')
for track_name in duplicate_tracks['Track'].unique():
    artist_count = duplicate_tracks[duplicate_tracks['Track'] == track_name]['Artist'].nunique()
    if artist_count > 1:
        print(f"\nTrack: {track_name}")
        display(duplicate_tracks[duplicate_tracks['Track'] == track_name][['Track', 'Artist', 'Album Name', 'Release Date']].head())
        count += 1
    if count >= 5:
        break

# Canciones y Artista iguales vs. Álbum o Lanzamiento distinto
count=0
print("\nEjemplos de tracks y artista duplicados pero álbum o lanzamiento distinto:")
for track_name in duplicate_tracks['Track'].unique():
    artist_groups = duplicate_tracks[duplicate_tracks['Track'] == track_name].groupby('Artist')
    for artist_name, artist_df in artist_groups:
        if len(artist_df) > 1:
            print(f"\nTrack: {track_name}, Artist: {artist_name}")
            display(artist_df[['Track', 'Artist', 'Album Name', 'Release Date']].head())
            count += 1
    if count >= 5:
        break
# Out:
# Ejemplos de tracks duplicados con artista diferente:
#
# Track: 23
#      Track             Artist  \
# 2527    23     Chayce Beckham
# 3424    23  Mike WiLL Made-It
#
#                                              Album Name Release Date
# 2527                                                 23    5/14/2021
# 3424  23 (feat. Miley Cyrus, Wiz Khalifa & Juicy J) ...     1/1/2013
# Track: 911
#      Track         Artist Album Name Release Date
# 2069   911           Sech        911     2/5/2021
# 2687   911  Fuerza Regida        911   11/30/2022
# Track: A Thousand Years
#                  Track           Artist        Album Name Release Date
# 2072  A Thousand Years      Aldy Santos  A Thousand Years    2/27/2017
# 962   A Thousand Years  Christina Perri  A Thousand Years   10/18/2011
# Track: Aesthetic
#          Track      Artist Album Name Release Date
# 113  Aesthetic  Tollan Kim  Aesthetic     3/4/2022
# 976  Aesthetic        Xilo  Aesthetic    2/14/2020
# Track: After Hours
# ...

# %%
# Canciones con mismo título pero artista diferente
duplicate_tracks_different_artists = df.groupby('Track').filter(lambda x: x['Artist'].nunique() > 1)
display(duplicate_tracks_different_artists.head())
# Out:
#                    Track                                    Album Name  \
# 3                Flowers                              Flowers - Single
# 4                Houdini                                       Houdini
# 8   Danza Kuduro - Cover  ýýýýýýýýýýýýýýýýýýýýý - ýýýýýýýýýýýýýýýýýý -
# 19             As It Was                                     As It Was
# 22  Danza Kuduro - Cover               CLUB DE YOKUKIKU YOUGAKU MEDLEY
#
#            Artist Release Date All Time Rank  Track Score Spotify Streams  \
# 3     Miley Cyrus    1/12/2023             4        444.9   2,031,280,633
# 4          Eminem    5/31/2024             5        423.3     107,034,922
# 8   MUSIC LAB JPN     6/9/2024             9        355.7   1,653,018,119
# 19   Harry Styles    3/31/2022            20        292.0   3,301,814,535
# 22  MUSIC LAB JPN    5/21/2024            23        279.0   1,655,575,417
#
#    Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  ...  \
# ...

# %%
# Mismos artistas y títulos vs. lanzamientos distintos
duplicate_same_artist = df.groupby(['Track', 'Artist']).filter(lambda x: len(x) > 1)

# Priorización
def prioritize_release(group):
    # Nos quedamos con filas originales (no versiones de recopilación, deluxe, video, etc.)
    original_releases = group[~group['Album Name'].str.contains('Now|Deluxe|Single|Official Video', case=False, na=False)]

    # Se da prioridad al lanzamiento original
    if not original_releases.empty:
        return original_releases.sort_values(by='Release Date').iloc[0]
    else:
        return group.sort_values(by='Release Date').iloc[0]

# Aplicación de la priorización a los que comparten mismo título y artista
prioritized_duplicates = duplicate_same_artist.groupby(['Track', 'Artist']).apply(prioritize_release).reset_index(drop=True)

# Nuevo df sin duplicados y con las aplicaciones
duplicate_indices = duplicate_same_artist.index
non_duplicate_df = df.drop(duplicate_indices)

# Se combinan los df sin duplicados
cleaned_df = pd.concat([non_duplicate_df, prioritized_duplicates], ignore_index=True)
df = cleaned_df

display(df.head())
display(df.info())
# Out:
# /tmp/ipython-input-3653703261.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   prioritized_duplicates = duplicate_same_artist.groupby(['Track', 'Artist']).apply(prioritize_release).reset_index(drop=True)
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3            Beautiful Things              Beautiful Things    Benson Boone
# 4  BAND4BAND (feat. Lil Baby)    BAND4BAND (feat. Lil Baby)     Central Cee
#
# ...

# %%
# Duplicados
remaining_duplicates = df[df.duplicated(subset=['Track', 'Artist', 'Album Name'], keep=False)].copy()

# Columnas con posibles 0s (numéricas)
numerical_cols = remaining_duplicates.select_dtypes(include=['float64', 'int64']).columns.tolist()

# 0s por fila
remaining_duplicates['zero_count'] = remaining_duplicates[numerical_cols].apply(lambda row: (row == 0).sum(), axis=1)

# Se orden por frecuencia de 0s y agrupan por duplicados (título - artista - álbum)
prioritized_by_zeros = remaining_duplicates.sort_values(by='zero_count').groupby(['Track', 'Artist', 'Album Name']).head(1)

# Df sin registros duplicados, pero sí priorizados
remaining_duplicate_indices = remaining_duplicates.index
non_remaining_duplicate_df = df.drop(remaining_duplicate_indices)

# Se combina el df limpio
cleaned_df_final = pd.concat([non_remaining_duplicate_df, prioritized_by_zeros.drop(columns='zero_count')], ignore_index=True)
df = cleaned_df_final

display(df.head())
display(df.info())
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3            Beautiful Things              Beautiful Things    Benson Boone
# 4  BAND4BAND (feat. Lil Baby)    BAND4BAND (feat. Lil Baby)     Central Cee
#
#   Release Date All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024             1        725.4     390,470,936
# 1     5/4/2024             2        545.9     323,703,884
# 2    3/19/2024             3        538.4     601,309,283
# 3    1/18/2024             7        407.2     900,158,751
# 4    5/23/2024            10        330.6      90,676,573
#
#   Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  ...  \
# 0                 30,716            196,631,588                92.0  ...
# ...

# %%
# Título - Artista - Álbum
mask_album = df.duplicated(subset=['Track', 'Artist', 'Album Name'], keep=False)
remaining_duplicates_album = df.loc[mask_album]

# Título - Artista
mask_artist = df.duplicated(subset=['Track', 'Artist'], keep=False)
remaining_duplicates_artist = df.loc[mask_artist]

# Resultados por Título - Artista - Álbum
print("Duplicados por Título - Artista - Álbum:")
display(remaining_duplicates_album)

# Resultados por Título - Artista
print("\nDuplicados por Título - Artista:")
display(remaining_duplicates_artist)

print(f"\nNo. de Duplicados por Título - Artista - Álbum: {len(remaining_duplicates_album)}")
print(f"No. de Duplicados por Título - Artista: {len(remaining_duplicates_artist)}")
# Out:
# Duplicados por Título - Artista - Álbum:
# Empty DataFrame
# Columns: [Track, Album Name, Artist, Release Date, All Time Rank, Track Score, Spotify Streams, Spotify Playlist Count, Spotify Playlist Reach, Spotify Popularity, YouTube Views, YouTube Likes, TikTok Posts, TikTok Likes, TikTok Views, YouTube Playlist Reach, Apple Music Playlist Count, AirPlay Spins, SiriusXM Spins, Deezer Playlist Count, Deezer Playlist Reach, Amazon Playlist Count, Pandora Streams, Pandora Track Stations, Shazam Counts, Explicit Track]
# Index: []
#
# [0 rows x 26 columns]
# Duplicados por Título - Artista:
# Empty DataFrame
# ...

# %% [markdown]
# ##Datos Numéricos y Categóricos (Encoding)

# %%
columns_to_convert = [
    'All Time Rank',

    'Spotify Streams',
    'Spotify Playlist Count',
    'Spotify Playlist Reach',

    'YouTube Views',
    'YouTube Likes',
    'YouTube Playlist Reach',

    'TikTok Posts',
    'TikTok Likes',
    'TikTok Views',

    'AirPlay Spins', 'SiriusXM Spins', 'Deezer Playlist Reach',
    'Pandora Streams',
    'Pandora Track Stations',

    'Shazam Counts'
]

for col in columns_to_convert:
    if col in df.columns and df[col].dtype == 'object':
        # Quitamos comas y pasamos a num, posibles nans se reemplazan por 0 otra vez
        df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', ''), errors='coerce')
        df[col] = df[col].fillna(0)

display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4488 entries, 0 to 4487
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4488 non-null   object
#  1   Album Name                  4488 non-null   object
#  2   Artist                      4483 non-null   object
#  3   Release Date                4488 non-null   object
#  4   All Time Rank               4488 non-null   int64
#  5   Track Score                 4488 non-null   float64
#  6   Spotify Streams             4488 non-null   int64
#  7   Spotify Playlist Count      4488 non-null   int64
#  8   Spotify Playlist Reach      4488 non-null   int64
#  9   Spotify Popularity          4488 non-null   float64
#  10  YouTube Views               4488 non-null   int64
#  11  YouTube Likes               4488 non-null   int64
#  12  TikTok Posts                4488 non-null   int64
# ...

# %%
# Conversión a fecha y extracción del mes y año (ints) del release
df['Release Date'] = pd.to_datetime(df['Release Date'], errors='coerce')
df['Release Month'] = df['Release Date'].dt.month
df['Release Year'] = df['Release Date'].dt.year

# Se busca evitar que el modelo memorice fechas y, en su lugar, trate de comprender relaciones entre artistas, tracks, por fecha (verano, mes, año)
df = df.drop(columns=['Release Date'])

display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4488 entries, 0 to 4487
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4488 non-null   object
#  1   Album Name                  4488 non-null   object
#  2   Artist                      4483 non-null   object
#  3   All Time Rank               4488 non-null   int64
#  4   Track Score                 4488 non-null   float64
#  5   Spotify Streams             4488 non-null   int64
#  6   Spotify Playlist Count      4488 non-null   int64
#  7   Spotify Playlist Reach      4488 non-null   int64
#  8   Spotify Popularity          4488 non-null   float64
#  9   YouTube Views               4488 non-null   int64
#  10  YouTube Likes               4488 non-null   int64
#  11  TikTok Posts                4488 non-null   int64
#  12  TikTok Likes                4488 non-null   int64
# ...

# %%
# Datos ordenados por artista, año y mes
df_sorted = df.sort_values(by=['Artist', 'Release Year', 'Release Month'])
display(df_sorted.head())
# Out:
#                                                   Track  \
# 2243                        Come and Say - Original Mix
# 3131                          ZEIT, DASS SICH WAS DREHT
# 4386                                  For the Last Time
# 1606  ...And to Those I Love, Thanks for Sticking Ar...
# 3563                                             Avalon
#
#                        Album Name       Artist  All Time Rank  Track Score  \
# 2243           Relyt Conections 3         "XY"           2379         29.2
# 3131    ZEIT, DASS SICH WAS DREHT    $OHO BANI           3291         23.9
# 4386            For the Last Time  $uicideboy$           4585         19.4
# 1606  STOP STARING AT THE SHADOWS  $uicideboy$           1709         35.3
# 3563                       Avalon  $uicideboy$           3723         22.2
#
#       Spotify Streams  Spotify Playlist Count  Spotify Playlist Reach  \
# 2243                0                       1                       9
# ...

# %%
# Hay artistas nulos, pero no cuentan con registros. Se eliminan (5 / 4888) = 0.102% de la data
df_sorted = df_sorted.dropna(subset=['Artist'])
display(df_sorted.head())
# Out:
#                                                   Track  \
# 2243                        Come and Say - Original Mix
# 3131                          ZEIT, DASS SICH WAS DREHT
# 4386                                  For the Last Time
# 1606  ...And to Those I Love, Thanks for Sticking Ar...
# 3563                                             Avalon
#
#                        Album Name       Artist  All Time Rank  Track Score  \
# 2243           Relyt Conections 3         "XY"           2379         29.2
# 3131    ZEIT, DASS SICH WAS DREHT    $OHO BANI           3291         23.9
# 4386            For the Last Time  $uicideboy$           4585         19.4
# 1606  STOP STARING AT THE SHADOWS  $uicideboy$           1709         35.3
# 3563                       Avalon  $uicideboy$           3723         22.2
#
#       Spotify Streams  Spotify Playlist Count  Spotify Playlist Reach  \
# 2243                0                       1                       9
# ...

# %%
cols_with_zero = []

for col in df.columns:
  if 0 in df[col].unique():
    cols_with_zero += [col]

# Se imputa mediana móvil artista por artista con window de 5 y 1 minperiod para calcular hasta primeras entradas.
for col in cols_with_zero[:-1]:
    rolling_median = df_sorted.groupby('Artist')[col].transform(lambda x: x.rolling(window=5, min_periods=1).median())

    # Imputación de valores SI Y SOLO SI la mediana móvil no es 0.
    df_sorted[col] = df_sorted.apply(lambda row: rolling_median[row.name] if row[col] == 0 and rolling_median[row.name] != 0 else row[col],
                                     axis=1)

# %%
artists_mean = df.groupby(['Artist'])[cols_with_zero[:-1]].mean().reset_index()

# Se asignará una media a cada artista por reproducciones, impacto en playlists, likes, spins y views
streams_cols = []
playlist_count_cols = []
playlist_reach_cols = []
likes_cols = []
views_cols = []
spins_cols = []

for col in artists_mean.columns:
  if "Streams" in col:
    streams_cols += [col]
  elif "Playlist Count" in col:
    playlist_count_cols += [col]
  elif "Playlist Reach" in col:
    playlist_reach_cols += [col]
  elif "Likes" in col:
    likes_cols += [col]
  elif "Views" in col:
    views_cols += [col]
  elif "Spins" in col:
    spins_cols += [col]

# %%
artists_mean['Streams Mean'] = artists_mean[streams_cols].mean(axis=1)
artists_mean['Playlist Count Mean'] = artists_mean[playlist_count_cols].mean(axis=1)
artists_mean['Playlist Reach Mean'] = artists_mean[playlist_reach_cols].mean(axis=1)
artists_mean['Likes Mean'] = artists_mean[likes_cols].mean(axis=1)
artists_mean['Views Mean'] = artists_mean[views_cols].mean(axis=1)
artists_mean['Spins Mean'] = artists_mean[spins_cols].mean(axis=1)

artists_mean.head()
# Out:
#         Artist  Spotify Streams  Spotify Playlist Count  \
# 0         "XY"              0.0                1.000000
# 1    $OHO BANI       54065563.0             7779.000000
# 2  $uicideboy$      188605270.0            46010.555556
# 3          &ME       34601626.0            34272.000000
# 4     (G)I-DLE      219234613.0            20092.000000
#
#    Spotify Playlist Reach  Spotify Popularity  YouTube Views  YouTube Likes  \
# 0            9.000000e+00                0.00   4.151591e+08      745345.00
# 1            9.672092e+06               73.00   6.744201e+06       72802.00
# 2            6.602650e+06               63.00   7.677397e+07      822896.00
# 3            1.491486e+07               65.00   0.000000e+00           0.00
# 4            9.513365e+06               51.25   3.013097e+08     3264112.75
#
#     TikTok Posts  TikTok Likes  TikTok Views  ...  Amazon Playlist Count  \
# 0       0.000000          0.00  0.000000e+00  ...               0.000000
# ...

# %%
artists_mean = artists_mean.drop(columns=streams_cols + playlist_count_cols + playlist_reach_cols + likes_cols + views_cols + spins_cols)

# %%
artists_mean = df.groupby(['Artist'])[["Spotify Playlist Count", "Spotify Playlist Reach", "Apple Music Playlist Count",
                                       "Deezer Playlist Count"]].mean().reset_index()
artists_mean = artists_mean.sort_values(by=["Spotify Playlist Count", "Spotify Playlist Reach", "Apple Music Playlist Count",
                                       "Deezer Playlist Count"], ascending=True)
artists_mean.head()
# Out:
#                Artist  Spotify Playlist Count  Spotify Playlist Reach  \
# 14      3 Palavrinhas                     0.0                     0.0
# 177        Baby Flaco                     0.0                     0.0
# 253     Bonnie Kimmel                     0.0                     0.0
# 254  BoomBoxRepairKit                     0.0                     0.0
# 283             CA3RD                     0.0                     0.0
#
#      Apple Music Playlist Count  Deezer Playlist Count
# 14                          0.0                    0.0
# 177                         0.0                    0.0
# 253                         0.0                    0.0
# 254                         0.0                    0.0
# 283                         0.0                    0.0

# %%
artists_labels = {}

for i, artist in enumerate(artists_mean['Artist']):
  artists_labels[artist] = i

# %%
df['Artist'] = df['Artist'].map(artists_labels)
df.head()
# Out:
#                         Track                    Album Name  Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   931.0
# 1                 Not Like Us                   Not Like Us  1800.0
# 2  i like the way you kiss me    I like the way you kiss me  1272.0
# 3            Beautiful Things              Beautiful Things  1388.0
# 4  BAND4BAND (feat. Lil Baby)    BAND4BAND (feat. Lil Baby)  1615.0
#
#    All Time Rank  Track Score  Spotify Streams  Spotify Playlist Count  \
# 0              1        725.4        390470936                   30716
# 1              2        545.9        323703884                   28113
# 2              3        538.4        601309283                   54331
# 3              7        407.2        900158751                   73118
# 4             10        330.6         90676573                   10400
#
#    Spotify Playlist Reach  Spotify Popularity  YouTube Views  ...  \
# ...

# %%
album_labels = {}
tracks_labels = {}

# %%
grouped_albums = df.groupby(['Artist', 'Album Name'])[["Spotify Playlist Count",
                                                       "Spotify Playlist Reach",
                                                       "Apple Music Playlist Count",
                                                       "Deezer Playlist Count"]].mean().reset_index().sort_values(
                                                           by=["Spotify Playlist Count",
                                                               "Spotify Playlist Reach",
                                                               "Apple Music Playlist Count",
                                                               "Deezer Playlist Count"], ascending=True)
grouped_songs = df.groupby(['Artist', 'Track'])[["Spotify Playlist Count",
                                                 "Spotify Playlist Reach",
                                                 "Apple Music Playlist Count",
                                                 "Deezer Playlist Count"]].mean().reset_index().sort_values(
                                                     by=["Spotify Playlist Count",
                                                         "Spotify Playlist Reach",
                                                         "Apple Music Playlist Count",
                                                         "Deezer Playlist Count"], ascending=True)

# %%
for artist in grouped_albums['Artist'].unique():
  artist_albums = grouped_albums[grouped_albums['Artist']==artist]
  for i, album in enumerate(artist_albums['Album Name'].unique()):
    album_labels[album] = i

df['Album Name'] = df['Album Name'].map(album_labels)

for artist in grouped_songs['Artist'].unique():
  artist_songs = grouped_songs[grouped_songs['Artist']==artist]
  for i, track in enumerate(artist_songs['Track'].unique()):
    tracks_labels[track] = i

df['Track'] = df['Track'].map(tracks_labels)
df.head()
# Out:
#    Track  Album Name  Artist  All Time Rank  Track Score  Spotify Streams  \
# 0    1.0         0.0   931.0              1        725.4        390470936
# 1    2.0         2.0  1800.0              2        545.9        323703884
# 2    1.0         1.0  1272.0              3        538.4        601309283
# 3    3.0         3.0  1388.0              7        407.2        900158751
# 4    1.0         1.0  1615.0             10        330.6         90676573
#
#    Spotify Playlist Count  Spotify Playlist Reach  Spotify Popularity  \
# 0                   30716               196631588                92.0
# 1                   28113               174597137                92.0
# 2                   54331               211607669                92.0
# 3                   73118               201585714                86.0
# 4                   10400               184199419                86.0
#
#    YouTube Views  ...  SiriusXM Spins  Deezer Playlist Count  \
# ...

# %% [markdown]
# #  Descriptive Statistics Analysis

# %% [markdown]
# ## Visualizing Data Distributions

# %%
plt.figure()
plt.hist(df['Spotify Streams'], bins='auto', color='green', edgecolor='black')
plt.title('Spotify Streams')
plt.xlabel('Streams')
plt.ylabel('Frecuencia de canciones')
plt.show()

# %% [markdown]
# En este histograma podemos observar que la mayor parte de las canciones de spotify son reproducidas muy pocas veces, esto se muestra en el pico que tenemos en nuestro primer grupo que esta cerca del 0 lo que nos indica que existe una gran cantidad de canciones que no son famosas.
#
# Mientras las reproducciones aumentan podemos que la caida es ligeramente "constante", a exepción del segundo grupo donde el número de canciones cae casi a la mitad, lo que nos da a enteder que las canciones más populares son muy pocas. Podemos asumir que las canciones que se encuentran de lado derecho son de artistas importantes o canciones emblemáticas.

# %%
plt.figure()
plt.hist(df['YouTube Views'], bins=50, color='red', edgecolor='black')
plt.title('Youtbe Views')
plt.xlabel('Vistas de videos')
plt.ylabel('Frecuencia de videos')
plt.show()

# %% [markdown]
# El histograma de vistas de Youtube tiene un comportamiento muy similar al de Spotify; el pico de lado izquierdo nos muestra que la mayor parte de los videos musicales tiene muy pocas vistas.
#
# Sin embargo a diferencia de Spotify podemos ver una caida abrupta de más de la mitad en la cantidad de videos virales pasando de alrededor de 3,500 a solo 600 vistas aproximadamente.
# Conforme aumentan las vistas podemos ver que el número de videos dismunuye cada vez más hasta el punto en el que no se alcanzan a ver los valores de lado izquierdo. Indicando que son muy pocos los videos musicales que alcanzan a tener una popularidad enorme y que a comparación de Spotify es mucho más dificil tener vistas en los videos que reproducciones en las canciones.

# %% [markdown]
# ##Measures of Central Tendency

# %%
plt.figure()
plt.boxplot(df['Spotify Streams'], orientation='horizontal')
plt.title('Spotify Streams')
plt.xlabel('Streams')
plt.show()

print(f"Spotify Streams\nMedia: {df['Spotify Streams'].mean():.2f}\nMediana: {df['Spotify Streams'].median()}")
# Out:
# Spotify Streams
# Media: 421913262.12
# Mediana: 222325248.5

# %%
plt.figure()
plt.boxplot(df['YouTube Views'], orientation='horizontal')
plt.title('Youtube Views')
plt.xlabel('Views')
plt.show()

print(f"Youtube Views\nMedia: {df['YouTube Views'].mean():.2f}\nMediana: {df['YouTube Views'].median()}")
# Out:
# Youtube Views
# Media: 376498150.66
# Mediana: 130719396.5

# %% [markdown]
# Como podemos ver en ambos boxplot la mediana, linea naranja, se mantiene cerca del centro de donde se junta la mayor cantidad de datos por que para obtenerla se deben de ordenar los números de mayor a menor y se toma el número que tenemos en medio de toda esta lista, este número nunca se verá afectado por las anomalias.
#
# Mientras tanto la media es muy suceptible a las anomalias ya que estas pueden cambiar drasticamente su valor; como podemos ver en las gráficas a pesar de que tenemos la mayor cantidad de datos recargados de lado derecho tenemos una cantidad considerable de anomalias de lado izquierdo con valores mucho más grandes, gracias a los datos recargados de lado derecho es que nuestra media también se mueve a la derecha.

# %% [markdown]
# ## Measures of Dispersion and Relative Variability

# %%
# Desviación estándar
std_popularity = df["Spotify Popularity"].std()
std_streams = df["Spotify Streams"].std()
std_views = df["YouTube Views"].std()

# Media de popularity (para CV)
mean_popularity = df["Spotify Popularity"].mean()
mean_streams = df["Spotify Streams"].mean()
mean_views = df["YouTube Views"].mean()

# Coeficiente de variación (CV = std / mean)
cv_popularity = (std_popularity / mean_popularity) * 100
cv_streams = (std_streams / mean_streams) * 100
cv_views = (std_views / mean_views) * 100

print("\nStandard Deviation:")
print(f"Spotify Popularity: {std_popularity:.2f}")
print(f"Spotify Streams: {std_streams:.2f}")
print(f"YouTube Views: {std_views:.2f}")

print("\nCoefficient of Variation (CV):")
print(f"Spotify Popularity: % {cv_popularity:.2f}")
print(f"Spotify Streams: % {cv_streams:.2f}")
print(f"YouTube Views: % {cv_views:.2f}")
# Out:
# Standard Deviation:
# Spotify Popularity: 27.90
# Spotify Streams: 520471499.33
# YouTube Views: 682954848.18
#
# Coefficient of Variation (CV):
# Spotify Popularity: % 52.73
# Spotify Streams: % 123.36
# YouTube Views: % 181.40

# %%
plt.figure()
plt.bar(['Spotify Popularity', 'Spotify Streams', 'YouTube Views'], [cv_popularity, cv_streams, cv_views])
plt.title('Coeficientes de variación')
plt.ylabel('Coeficiente de Variación')
plt.show()

# %% [markdown]
# Como podemos ver en la gráfica de barras nuestros coeficientes tiene diferentes porcentajes, siendo la popularidad en Spotify la más pequeña con un CV de 52.73%, lo que nos indica que la probabilidad de que una canción sea popular es algo equitativa.
#
# En Spotify streams podemos ver un brinco de un poco más del doble, lo que nos indica que existe una mayor variedad de posibles resultados para una canción, es decir, se vuelve muy complejo calcular si una canción tendrá muchos Streams o no, demostrando el dominio que tienen pocas canciones.
#
# Por ultimo, podemos ver que el CV de Youtube es el más alto de todos. Relacionandolo con el comportamiento de las gráficas de arriba podemos concluir que la competencia de videos musicales es mucho mas agresiva/competitiva a diferencia de Spotify.

# %% [markdown]
# #Probabilistic Analysis with Bayes' Theorem

# %% [markdown]
# ##  Defining Events

# %%
df['Has_High_Popularity'] = (df['Spotify Popularity'] >= 85).astype(int)
df['Is_Explicit'] = (df['Explicit Track'] == 1).astype(int)
df
# Out:
#       Track  Album Name  Artist  All Time Rank  Track Score  Spotify Streams  \
# 0       1.0         0.0   931.0              1        725.4        390470936
# 1       2.0         2.0  1800.0              2        545.9        323703884
# 2       1.0         1.0  1272.0              3        538.4        601309283
# 3       3.0         3.0  1388.0              7        407.2        900158751
# 4       1.0         1.0  1615.0             10        330.6         90676573
# ...     ...         ...     ...            ...          ...              ...
# 4483    3.0         1.0  1410.0            831         53.2         58469975
# 4484    8.0         4.0  1630.0             87        164.8        428233003
# 4485    7.0         4.0  1688.0            138        128.9        998964097
# 4486    4.0         1.0  1566.0            199        107.5        416813996
# 4487    1.0         1.0  1444.0           2855         26.1        311307250
#
# ...

# %% [markdown]
# ##Calculating Prior Probabilities

# %%
p_A = df["Has_High_Popularity"].mean()
p_B = df["Explicit Track"].mean()
p_A_given_B = df.loc[df["Explicit Track"] == 1, "Has_High_Popularity"].mean()

print("P(A)  =", p_A)
print("P(B)  =", p_B)
print("P(A|B) =", p_A_given_B)
# Out:
# P(A)  = 0.011140819964349376
# P(B)  = 0.3589572192513369
# P(A|B) = 0.00931098696461825

# %% [markdown]
# ## Applying Bayes' Theorem

# %% [markdown]
# ### Teorema de Bayes aplicado
#
# El **Teorema de Bayes** nos permite invertir probabilidades condicionales:
#
# $$ P(B | A) = \frac{P(A | B) \cdot P(B)}{P(A)} $$
#
# donde:
#
# - **P(A):** Probabilidad de que una canción sea muy popular.
# - **P(B):** Probabilidad de que una canción sea explícita.
# - **P(A|B):** Probabilidad de que una canción sea muy popular dado que es explícita.
# - **P(B|A):** Probabilidad de que una canción sea explícita dado que es muy popular.
#
# Con el teorema de Bayes, pasamos de **P(A|B)** (ya conocida del dataset) a **P(B|A)**, usando la probabilidad total de A.

# %%
# Teorema de Bayes P (B | A) = P(A | B) P(B) / P(A)
p_B_given_A = (p_A_given_B * p_B) / p_A

print(f"Si seleccionamos una canción al azar y resulta ser muy popular,\nsu probabilidad de que sea explícita es P(B|A) = {p_B_given_A:.4f}")

# Comparación
if p_B_given_A > p_B:
    print("\nSi una canción es muy popular, entonces es más probable que sea explícita.")
elif p_B_given_A < p_B:
    print("\nSi una canción es muy popular, entonces es menos probable que sea explícita.")
else:
    print("\nQue una canción sea muy popular NO cambia la probabilidad de que sea explícita.")
# Out:
# Si seleccionamos una canción al azar y resulta ser muy popular,
# su probabilidad de que sea explícita es P(B|A) = 0.3000
#
# Si una canción es muy popular, entonces es menos probable que sea explícita.
